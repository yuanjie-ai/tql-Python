# %%
# %matplotlib inline
import gc
gc.collect()
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
# sns.set(style="white", color_codes=True)
import matplotlib.pyplot as plt
iris = sns.load_dataset('iris')

# %%
iris = sns.load_dataset('iris');iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns = ['a','b','c','d','label']

# %%
# 描述性统计
iris.describe()
# Out:
#                 a           b           c           d
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# label分布
iris.label.value_counts()
iris.label.value_counts().plot(kind='pie',figsize=(3, 3),)

# %%
# 自变量坐标分布
sns.FacetGrid(iris, hue="label", size=5) \
   .map(plt.scatter, "a", "b") \
   .add_legend()
sns.jointplot(x="a", y="b", data=iris)

# %%
# 单个特征的箱形图
sns.boxplot(x="label", y="d", data=iris)

# %%
# 多个特征的箱形图
iris.boxplot()

# %%
iris.boxplot(by="label", figsize=(12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f55e8519ac8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f55e8375da0>]], dtype=object)

# %%
sns.boxplot(data=iris)

# %%
# 单个特征的散点分布
ax = sns.boxplot(x="label", y="c", data=iris)
ax = sns.stripplot(x="label", y="c", data=iris, jitter=True, edgecolor="gray")
sns.violinplot(x="label", y="c", data=iris, size=6)

# %%
# 海底分布图
sns.FacetGrid(iris, hue="label", size=5) \
   .map(sns.kdeplot, "c") \
   .add_legend()

# %%
iris.b.value_counts().sort_index().plot(kind='bar')

# %%
iris

# %%
sns.pairplot(iris, hue="label", size=3)

# %%
sns.pairplot(iris, hue="label", size=3, diag_kind="kde")

# %%
# Andrews Curves涉及使用样本的属性作为傅里叶级数的系数
from pandas.tools.plotting import andrews_curves
andrews_curves(iris[['a','b','label']], "label")

# %%
from pandas.tools.plotting import parallel_coordinates
parallel_coordinates(iris, "label")

# %%
from pandas.tools.plotting import radviz
radviz(iris, "label")

# %%
radviz?
